# %% [markdown]
# ### Импорты

# %%
import sqlite3
import json
import natasha
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    NewsNERTagger,
    
    PER,
    NamesExtractor,

    Doc
)


segmenter = Segmenter()
morph_vocab = MorphVocab()

emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
ner_tagger = NewsNERTagger(emb)

names_extractor = NamesExtractor(morph_vocab)

# %%
from pymystem3 import Mystem

# %%
import wget

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

def lemmatization(token):
    p = morph.parse(token)[0]
    return p.normal_form

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import tokenize
from gensim.summarization.textcleaner import split_sentences

# %%
from tqdm.auto import tqdm

# %%
from threading import Thread

# %% [markdown]
# Скачиваем модель русских новостей

# %%
import zipfile
model_url = 'http://vectors.nlpl.eu/repository/20/186.zip'
m = wget.download(model_url)
model_file = model_url.split('/')[-1]
with zipfile.ZipFile(model_file, 'r') as archive:
    stream = archive.open('model.bin')
    model = gensim.models.KeyedVectors.load_word2vec_format(stream, binary=True)
# Out:
# 100% [......................................................................] 640473374 / 640473374

# %% [markdown]
# Маппинг pos-тегов

# %%
import requests
import re

url = 'https://raw.githubusercontent.com/akutuzov/universal-pos-tags/4653e8a9154e93fe2f417c7fdb7a357b7d6ce333/ru-rnc.map'

mapping = {}
r = requests.get(url, stream=True)
for pair in r.text.split('\n'):
    pair = re.sub('\s+', ' ', pair, flags=re.U).split(' ')
    if len(pair) > 1:
        mapping[pair[0]] = pair[1]

# %% [markdown]
# Функция, которая размечает слова для получения синонимов и конвертирует pos-теги

# %%
def tag_mystem(text):  
    m = Mystem()
    w = m.analyze(text)[0]
    print(w)
    tagged = []
    try:
        if len(w["analysis"]) == 0:
            tagged.append(text + '_X')
        else:
            lemma = w["analysis"][0]["lex"]
            pos = w["analysis"][0]["gr"].split(',')[0]
            pos = pos.split('=')[0]
            if pos in mapping:
                tagged.append(lemma + '_' + mapping[pos]) # здесь мы конвертируем тэги
            else:
                tagged.append(lemma + '_X') # на случай, если попадется тэг, которого нет в маппинге
    except KeyError:
        pass # я здесь пропускаю знаки препинания, но вы можете поступить по-другому
    return tagged

# %% [markdown]
# Функция для лемматизации токена

# %%
def lemmatization(token):
    p = morph.parse(token)[0]
    return p.normal_form
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-fb72780078a7> in <module>
#       2 doc.segment(segmenter)
#       3 doc.tag_morph(morph_tagger)
# ----> 4 doc.lemmatize(morph_vocab)
#
# AttributeError: 'Doc' object has no attribute 'lemmatize'

# %% [markdown]
# Функция, которая сохраняет токены с информацией о них (в каких постах упоминались и айди синонимов) в формате словаря

# %%
def tokens_to_db(texts, posts_id):
    toks = {}
    for a in range(len(texts)):
        doc = Doc(texts[a])
        doc.segment(segmenter)
        doc.tag_morph(morph_tagger)
        morph_vocab = MorphVocab()
        for tok in doc.tokens:
            if tok.pos != 'PUNCT':
                if tok.text.lower() in toks.keys():
                    if posts_id[a] not in toks[tok.text.lower()]['list_posts_id']:
                        toks[tok.text.lower()]['list_posts_id'].append(posts_id[a])
                else:
                    tok.lemmatize(morph_vocab)
                    toks[tok.text.lower()] = {}
                    toks[tok.text.lower()]['list_posts_id'] = [posts_id[a]]
                    toks[tok.text.lower()]['list_synonyms'] = []
                    #for_m = tok.lemma+'_'+tok.pos
                    #try:
                        #for j in model.most_similar(positive=[for_m], topn=2):
                            #toks[tok.text.lower()]['list_synonyms'].append(j[0].split('_')[0])
                    #except:
                        #toks[tok.text.lower()]['list_synonyms'] = []
    tokens_json.update(toks)

# %% [markdown]
# Функция, которая сохраняет леммы и информацию о них (к каким токенам принадлежит) в формате словаря

# %%
def lemmas_to_db(tokens):
    for tok in tokens:
        lem = lemmatization(tok)
        id_t = tokens_json[tok] 
        if lem in lemmas_json.keys():
            if id_t not in lemmas_json[lem]['list_tokens']:
                lemmas_json[lem]['list_tokens'].append(id_t)
        else:
            lemmas_json[lem] = {}
            lemmas_json[lem]['list_tokens'] = [id_t]

# %% [markdown]
# ### Подключаемся к бд

# %%
con = sqlite3.connect('telegram.db')

# %%
c = con.cursor()
con.commit()

# %% [markdown]
# Создаём таблицы

# %%
c.execute(
        '''CREATE TABLE IF NOT EXISTS tokens (
            id_token integer PRIMARY KEY,
            token text NOT NULL,
            list_posts_id text,
            list_synonyms text);''')
con.commit()

# %%
c.execute(
        '''CREATE TABLE IF NOT EXISTS lemmas (
            id_lemma integer PRIMARY KEY,
            lemma text NOT NULL,
            list_tokens text);''')
con.commit()

# %% [markdown]
# В несколько потоков обрабатываем токены

# %%
tokens_json = {}
texts = []
posts_id = []
for row in tqdm(c.execute("""SELECT text, posts_id FROM posts""")):
    texts.append(row[-2])
    posts_id.append(row[-1])
threads = []
for i in tqdm(range(0, len(texts), 4000)):
    th_texts = texts[i:i+4000]
    th_posts_id = posts_id[i:i+4000]
    thr = Thread(target=tokens_to_db, args=(th_texts, th_posts_id))
    threads.append(thr)
    thr.start()
for thr in tqdm(threads):
    thr.join()

# %% [markdown]
# В несколько потоков обрабатываем леммы

# %%
tokens_json = {}
lemmas_json = {}
texts = []
posts_id = []
tokens = []
for row in tqdm(c.execute("""SELECT id_token, token FROM tokens""")):
    if row[-1] not in tokens_json.keys():
        tokens_json[row[-1]] = ''
    tokens_json[row[-1]] = row[-2]
threads = []
for i in tqdm(range(0, len(tokens_json), 10000)):
    th_tokens = [k for k, v in tokens_json.items() if (i<=v)and(v<i+10000)]
    thr = Thread(target=lemmas_to_db, args=(th_tokens,))
    threads.append(thr)
    thr.start()
for thr in tqdm(threads):
    thr.join()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))

# %% [markdown]
# Записываем в бд

# %%
tokens_db = tokens_to_db()
i=0
for k, v in tqdm(tokens_json.items()):
    c.execute(
        'INSERT INTO tokens VALUES (?, ?, ?, ?)',
        (i, k, str(v['list_posts_id']), str(v['list_synonyms']))
)
    i+=1
con.commit()

i=0
lemmas_db = lemmas_to_db()
for k, v in tqdm(lemmas_json.items()):
    c.execute(
        'INSERT INTO lemmas VALUES (?, ?, ?)',
        (i, k, str(v['list_tokens']))
    )
    i+=1

con.commit()
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-103f7b2ffece> in <module>
# ----> 1 tokens_db = tokens_to_db()
#       2 i=0
#       3 for k, v in tqdm(tokens_db.items()):
#       4     c.execute(
#       5         'INSERT INTO tokens VALUES (?, ?, ?, ?)',
#
# <ipython-input-6-bb714c609907> in tokens_to_db()
#       7         doc.segment(segmenter)
#       8         doc.tag_morph(morph_tagger)
# ----> 9         morph_vocab = MorphVocab()
#      10         for tok in doc.tokens:
#      11             if tok.pos != 'PUNCT':
#
# ~\Anaconda3\lib\site-packages\natasha\morph\vocab.py in __init__(self)
#     160 class MorphVocab(PymorphyAnalyzer):
#     161     def __init__(self):
# --> 162         PymorphyAnalyzer.__init__(self, result_type=MorphForm)
#     163
#     164     parse = lru_cache(CACHE_SIZE)(PymorphyAnalyzer.parse)
#
# ~\Anaconda3\lib\site-packages\pymorphy2\analyzer.py in __init__(self, path, result_type, units, probability_estimator_cls)
#     172         path = self.choose_dictionary_path(path)
#     173         with threading.RLock():
# --> 174             self.dictionary = opencorpora_dict.Dictionary(path)
#     175             if probability_estimator_cls is None:
#     176                 probability_estimator_cls = DummySingleTagProbabilityEstimator
#
# ~\Anaconda3\lib\site-packages\pymorphy2\opencorpora_dict\wrapper.py in __init__(self, path)
#      16         logger.info("Loading dictionaries from %s", path)
#      17
# ---> 18         self._data = load_dict(path)
#      19
#      20         logger.info("format: %(format_version)s, revision: %(source_revision)s, updated: %(compiled_at)s", self._data.meta)
#
# ~\Anaconda3\lib\site-packages\pymorphy2\opencorpora_dict\storage.py in load_dict(path, gramtab_format)
#      49
#      50     str_gramtab = _load_gramtab(meta, gramtab_format, path)
# ---> 51     gramtab = [Tag(tag_str) for tag_str in str_gramtab]
#      52
#      53     suffixes = json_read(_f('suffixes.json'))
#
# ~\Anaconda3\lib\site-packages\pymorphy2\opencorpora_dict\storage.py in <listcomp>(.0)
#      49
#      50     str_gramtab = _load_gramtab(meta, gramtab_format, path)
# ---> 51     gramtab = [Tag(tag_str) for tag_str in str_gramtab]
#      52
#      53     suffixes = json_read(_f('suffixes.json'))
#
# ~\Anaconda3\lib\site-packages\pymorphy2\tagset.py in __init__(self, tag)
#     275         # - grammemes are interned.
#     276         grammemes = tag.replace(' ', ',', 1).split(',')
# --> 277         grammemes_tuple = tuple([intern(str(g)) for g in grammemes])
#     278
#     279         self._assert_grammemes_are_known(set(grammemes_tuple))
#
# ~\Anaconda3\lib\site-packages\pymorphy2\tagset.py in <listcomp>(.0)
#     275         # - grammemes are interned.
#     276         grammemes = tag.replace(' ', ',', 1).split(',')
# --> 277         grammemes_tuple = tuple([intern(str(g)) for g in grammemes])
#     278
#     279         self._assert_grammemes_are_known(set(grammemes_tuple))
#
# KeyboardInterrupt:

# %% [markdown]
# Всё то же самое для токенов (не хватило мощности)

# %%
def get_synonyms(tokens):
    for tok in tokens:
        for_m = tag_mystem(tok)
        try:
            for j in model.most_similar(positive=[for_m], topn=2):
                synonyms_db[tok]['list_synonyms'].append(j[0].split('_')[0])
        except:
            synonyms_db[tok] = {}
            synonyms_db[tok]['list_synonyms'] = []

# %%
threads = []
synonyms_db = {}
for i in tqdm(range(0, len(tokens_json), 10000)):
    th_tokens = [k for k, v in tokens_json.items() if (i<=v)and(v<i+10000)]
    thr = Thread(target=get_synonyms, args=(th_tokens,))
    threads.append(thr)
    thr.start()
for thr in tqdm(threads):
    thr.join()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9.0), HTML(value='')))
# {'analysis': [{'lex': 'сначала', 'wt': 1, 'gr': 'ADV='}], 'text': 'сначала'}
# {'analysis': [{'lex': 'энергичность', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'энергичность'}
# {'analysis': [{'lex': 'думать', 'wt': 0.9505485925, 'gr': 'V,несов,нп=непрош,вин,ед,прич,полн,жен,действ'}], 'text': 'думающую'}{'analysis': [{'lex': 'долгожданный', 'wt': 1, 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}], 'text': 'долгожданным'}
#
# {'analysis': [{'lex': 'исключение', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'исключение'}
# {'analysis': [], 'text': 'pfizer'}
# {'analysis': [{'lex': 'выявлять', 'wt': 1, 'gr': 'V,пе=(прош,пр,мн,прич,полн,сов,страд|прош,вин,мн,прич,полн,сов,страд,од|прош,род,мн,прич,полн,сов,страд)'}], 'text': 'выявленных'}
# {'analysis': [], 'text': 'yrak'}
# {'analysis': [{'lex': 'ход', 'wt': 0.9991030624, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'ходы'}
# {'analysis': [{'lex': 'центр', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}], 'text': 'центром'}
# {'analysis': [{'lex': 'рассчитать', 'wt': 1, 'gr': 'V,сов,пе=прош,ед,прич,кр,муж,страд'}], 'text': 'рассчитан'}
# {'analysis': [{'lex': 'замечать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,несов'}], 'text': 'замечали'}
# {'analysis': [{'lex': 'почетный', 'wt': 1, 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}], 'text': 'почетным'}
# {'analysis': [{'lex': 'мужчина', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'мужчиной'}{'analysis': [{'lex': 'физически', 'wt': 0.9996301365, 'gr': 'ADV='}], 'text': 'физически'}
#
# {'analysis': [{'lex': 'случай', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}], 'text': 'случаев'}
# {'analysis': [], 'text': 'aaidsqdk'}
# {'analysis': [{'lex': 'записывать', 'wt': 1, 'gr': 'V,пе=прош,мн,прич,кр,сов,страд'}], 'text': 'записаны'}
# {'analysis': [{'lex': 'корпорация', 'wt': 1, 'gr': 'S,жен,неод=твор,мн'}], 'text': 'корпорациями'}
# {'analysis': [{'lex': 'думаться', 'wt': 1, 'gr': 'V,несов,нп=непрош,ед,изъяв,3-л'}], 'text': 'думается'}{'analysis': [{'lex': 'ошибка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'ошибку'}
#
# {'analysis': [{'lex': 'новый', 'wt': 0.9997324275, 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'новой'}{'analysis': [{'lex': 'заходить', 'wt': 0.9758000596, 'gr': 'V,несов,нп=прош,ед,изъяв,муж'}], 'text': 'заходил'}
#
# {'analysis': [{'lex': 'формулировка', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'формулировки'}
# {'analysis': [{'lex': 'звание', 'wt': 1, 'gr': 'S,сред,неод=твор,ед'}], 'text': 'званием'}
# {'analysis': [], 'text': 'zlz'}
# {'analysis': [{'lex': 'рассказывать', 'wt': 1, 'gr': 'V=(непрош,вин,ед,прич,полн,муж,несов,действ,неод,пе|непрош,им,ед,прич,полн,муж,несов,действ,пе)'}], 'text': 'рассказывающий'}
# {'analysis': [{'lex': 'ограниченность', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'ограниченности'}
# {'analysis': [{'lex': 'четкий', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}], 'text': 'четкого'}
# {'analysis': [{'lex': 'коронавирусный', 'wt': 0.858107934, 'qual': 'bastard', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'коронавирусной'}{'analysis': [{'lex': 'сдавать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,несов'}], 'text': 'сдавали'}{'analysis': [{'lex': 'женский', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'женский'}
#
#
# {'analysis': [{'lex': 'преданный', 'wt': 0.8115718613, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'преданные'}
# {'analysis': [], 'text': 'ekg'}
# {'text': '35'}
# {'analysis': [{'lex': 'щадить', 'wt': 1, 'gr': 'V,несов,пе=непрош,ед,изъяв,3-л'}], 'text': 'щадит'}
# {'analysis': [{'lex': 'текслер', 'wt': 0.7324094467, 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'текслер'}
# {'analysis': [{'lex': 'коммуникация', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'коммуникации'}
# {'analysis': [{'lex': 'квартальный', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}], 'text': 'квартальную'}{'analysis': [{'lex': 'туалет', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'туалет'}
#
# {'analysis': [{'lex': 'инфекция', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'инфекции'}
# {'analysis': [{'lex': 'дорожероссия', 'wt': 0.4259513018, 'qual': 'bastard', 'gr': 'S,жен,неод=им,ед'}], 'text': 'дорожероссия'}
# {'analysis': [{'lex': 'адепт', 'wt': 1, 'gr': 'S,муж,од=им,мн'}], 'text': 'адепты'}
# {'analysis': [{'lex': 'темный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'тёмный'}
# {'analysis': [{'lex': 'пойти', 'wt': 1, 'gr': 'V,сов,нп=прош,деепр'}], 'text': 'пойдя'}
# {'analysis': [{'lex': 'встраивать', 'wt': 1, 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}], 'text': 'встраивает'}
# {'analysis': [{'lex': 'отчетность', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'отчетность'}
# {'analysis': [{'lex': 'ад', 'wt': 0.9998469519, 'gr': 'S,ед,муж,неод=(вин|им)'}], 'text': 'ад'}
# {'analysis': [{'lex': 'заменять', 'wt': 1, 'gr': 'V,пе=(непрош,пр,ед,прич,полн,жен,несов,страд|непрош,дат,ед,прич,полн,жен,несов,страд|непрош,род,ед,прич,полн,жен,несов,страд|непрош,твор,ед,прич,полн,жен,несов,страд)'}], 'text': 'заменяемой'}
# {'analysis': [{'lex': 'в', 'wt': 8.212235587e-06, 'gr': 'S,сокр=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}], 'text': 'в'}
# {'analysis': [{'lex': 'рыцарь', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'рыцарь'}
# {'analysis': [{'lex': 'грабеж', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}], 'text': 'грабежом'}
# {'analysis': [{'lex': 'односторонний', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'односторонних'}
# {'analysis': [{'lex': 'духовный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}], 'text': 'духовного'}
# {'analysis': [{'lex': 'размытие', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'размытия'}{'analysis': [{'lex': 'орел', 'wt': 0.3890121558, 'gr': 'S,муж,од=(вин,мн|род,мн)'}], 'text': 'орлов'}
#
# {'analysis': [{'lex': 'россия', 'wt': 1, 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'россии'}{'analysis': [{'lex': 'обнаруживать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,сов'}], 'text': 'обнаружили'}
#
# {'analysis': [{'lex': 'обсуждать', 'wt': 1, 'gr': 'V=непрош,деепр,несов,пе'}], 'text': 'обсуждая'}
# {'analysis': [{'lex': 'сжирать', 'wt': 1, 'gr': 'V,пе=инф,сов'}], 'text': 'сожрать'}
# {'analysis': [{'lex': 'благоприятный', 'wt': 1, 'gr': 'A=мн,кр'}], 'text': 'благоприятны'}
# {'analysis': [{'lex': 'расскрывать', 'wt': 0.4164084206, 'qual': 'bastard', 'gr': 'V=(непрош,мн,изъяв,1-л,несов,пе|непрош,ед,прич,кр,муж,несов,страд,пе)'}], 'text': 'расскрываем'}
# {'analysis': [{'lex': 'украсть', 'wt': 1, 'gr': 'V,сов,пе=прош,мн,прич,кр,страд'}], 'text': 'украдены'}
# {'analysis': [{'lex': 'регистрироваться', 'wt': 1, 'gr': 'V,несов,нп=инф'}], 'text': 'регистрироваться'}
# {'analysis': [{'lex': 'нехилый', 'wt': 1, 'qual': 'bastard', 'gr': 'A=вин,ед,полн,жен'}], 'text': 'нехилую'}
# {'analysis': [{'lex': 'предпочтение', 'wt': 1, 'gr': 'S,сред,неод=род,мн'}], 'text': 'предпочтений'}
# {'analysis': [{'lex': 'прогнозировать', 'wt': 1, 'gr': 'V,несов,пе=ед,пов,2-л'}], 'text': 'прогнозируй'}{'analysis': [{'lex': 'преодолевать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,сред,сов'}], 'text': 'преодолело'}
#
# {'analysis': [{'lex': 'партнерство', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}], 'text': 'партнерстве'}
# {'analysis': [{'lex': 'нежелательно', 'wt': 0.7157431213, 'gr': 'ADV='}], 'text': 'нежелательно'}
# {'analysis': [{'lex': 'положенный', 'wt': 0.06498955071, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'положенные'}
# {'analysis': [{'lex': 'выявлять', 'wt': 1, 'gr': 'V,пе=(непрош,мн,изъяв,1-л,несов|непрош,ед,прич,кр,муж,несов,страд)'}], 'text': 'выявляем'}
# {'analysis': [{'lex': 'велеть', 'wt': 0.9919241401, 'gr': 'V,нп=(непрош,ед,изъяв,3-л,несов|непрош,ед,изъяв,3-л,сов)'}], 'text': 'велит'}
# {'analysis': [{'lex': 'бюджет', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'бюджете'}
# {'analysis': [{'lex': 'вычеркивать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,несов'}], 'text': 'вычеркивали'}
# {'analysis': [{'lex': 'психологический', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}], 'text': 'психологическую'}
# {'analysis': [{'lex': 'сырьевой', 'wt': 1, 'gr': 'A=твор,мн,полн'}], 'text': 'сырьевыми'}
# {'analysis': [{'lex': 'лебедь', 'wt': 0.8551318056, 'gr': 'S,муж,од=им,ед'}], 'text': 'лебедь'}
# {'analysis': [{'lex': 'тегеран', 'wt': 1, 'gr': 'S,гео,муж,неод=пр,ед'}], 'text': 'тегеране'}
# {'analysis': [{'lex': 'продавливать', 'wt': 1, 'gr': 'V,пе=непрош,деепр,несов'}], 'text': 'продавливая'}
# {'analysis': [{'lex': 'узнавать', 'wt': 1, 'gr': 'V,пе=ед,пов,2-л,сов'}], 'text': 'узнай'}
# {'analysis': [{'lex': 'девушка', 'wt': 1, 'gr': 'S,жен,од=(вин,мн|род,мн)'}], 'text': 'девушек'}
# {'analysis': [{'lex': 'непонятный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'непонятный'}
# {'analysis': [{'lex': 'рома', 'wt': 0.4195457435, 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'рома'}
# {'analysis': [{'lex': 'нежданчик', 'wt': 0.4221455848, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'нежданчик'}
# {'analysis': [{'lex': 'отметка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'отметку'}
# {'analysis': [{'lex': 'вершина', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'вершины'}
# {'analysis': [{'lex': 'уникальный', 'wt': 1, 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}], 'text': 'уникальном'}
# {'analysis': [{'lex': 'превосходить', 'wt': 1, 'gr': 'V,пе=инф,сов'}], 'text': 'превзойти'}{'analysis': [{'lex': 'живьем', 'wt': 1, 'gr': 'ADV='}], 'text': 'живьем'}
#
# {'analysis': [{'lex': 'уверять', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,несов'}], 'text': 'уверял'}
# {'analysis': [{'lex': 'в', 'wt': 0.9999917878, 'gr': 'PR='}], 'text': 'в'}
# {'analysis': [{'lex': 'тусовка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'тусовка'}
# {'analysis': [{'lex': 'волга', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}], 'text': 'волге'}
# {'text': '20'}
# {'analysis': [{'lex': 'губернатор', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'губернатор'}
# {'analysis': [{'lex': 'постправда', 'wt': 0.4392239657, 'qual': 'bastard', 'gr': 'ADV,прдк='}], 'text': 'постправда'}
# {'analysis': [{'lex': 'чернозем', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'чернозем'}
# {'analysis': [{'lex': 'конституционный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'конституционный'}
# {'analysis': [{'lex': 'делать', 'wt': 1, 'gr': 'V,несов,пе=прош,ед,изъяв,муж'}], 'text': 'делал'}
# {'analysis': [{'lex': 'заказчик', 'wt': 1, 'gr': 'S,муж,од=им,мн'}], 'text': 'заказчики'}
# {'analysis': [{'lex': 'перевертываться', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,жен,сов'}], 'text': 'перевернулась'}
# {'text': '000'}
# {'analysis': [{'lex': 'клуб', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'клубе'}
# {'analysis': [{'lex': 'новгородский', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'новгородская'}
# {'analysis': [{'lex': 'актуальный', 'wt': 1, 'gr': 'A=(пр,мн,полн,прев|вин,мн,полн,прев,од|род,мн,полн,прев)'}], 'text': 'актуальнейших'}
# {'analysis': [{'lex': 'противоречиев', 'wt': 0.9707057971, 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'противоречиев'}
# {'analysis': [{'lex': 'поморщиться', 'wt': 1, 'gr': 'V,сов,нп=непрош,мн,изъяв,3-л'}], 'text': 'поморщатся'}
# {'analysis': [{'lex': 'материальчик', 'wt': 0.5369848155, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'материальчик'}
# {'analysis': [{'lex': 'банковский', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'банковская'}
# {'analysis': [{'lex': 'ася', 'wt': 1, 'gr': 'S,имя,жен,од=(род,ед|им,мн)'}], 'text': 'аси'}
# {'analysis': [{'lex': 'лодка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'лодка'}{'analysis': [{'lex': 'неожиданно', 'wt': 0.9909456037, 'gr': 'ADV='}], 'text': 'неожиданно'}
#
# {'analysis': [{'lex': 'интересный', 'wt': 1, 'gr': 'A=ед,кр,жен'}], 'text': 'интересна'}
# {'analysis': [{'lex': 'аксессуар', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}], 'text': 'аксессуаров'}
# {'analysis': [{'lex': 'живодер', 'wt': 1, 'gr': 'S,муж,од=дат,мн'}], 'text': 'живодерам'}
# {'analysis': [{'lex': 'инсайд', 'wt': 1, 'gr': 'S,муж,од=пр,мн'}], 'text': 'инсайдах'}
# {'analysis': [{'lex': 'дисциплина', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'дисциплину'}
# {'analysis': [{'lex': 'стиль', 'wt': 1, 'gr': 'S,муж,неод=дат,ед'}], 'text': 'стилю'}
# {'analysis': [{'lex': 'ошибка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'ошибка'}
# {'analysis': [{'lex': 'маркетолог', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'маркетолог'}
# {'analysis': [{'lex': 'десять', 'wt': 0.9512489938, 'gr': 'NUM=твор'}], 'text': 'десятью'}
# {'analysis': [{'lex': 'такой', 'wt': 1, 'gr': 'APRO=(вин,ед,сред|им,ед,сред)'}], 'text': 'такое'}
# {'analysis': [{'lex': 'наручный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'наручный'}
# {'analysis': [{'lex': 'обсуждать', 'wt': 1, 'gr': 'V=(непрош,вин,ед,прич,полн,муж,несов,страд,неод,пе|непрош,им,ед,прич,полн,муж,несов,страд,пе)'}], 'text': 'обсуждаемый'}
# {'analysis': [{'lex': 'доктрина', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'доктрину'}
# {'analysis': [{'lex': 'посоветовать', 'wt': 1, 'gr': 'V,сов,пе=прош,ед,изъяв,муж'}], 'text': 'посоветовал'}
# {'analysis': [{'lex': 'впечатлиться', 'wt': 0.3733797748, 'qual': 'bastard', 'gr': 'V,несов,нп=прош,ед,изъяв,муж'}], 'text': 'впечатлился'}
# {'analysis': [{'lex': 'фок', 'wt': 0.9853476461, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'фок'}
# {'analysis': [{'lex': 'тупизна', 'wt': 0.5407853032, 'qual': 'bastard', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'тупизны'}
# {'analysis': [], 'text': 'aromath'}
# {'analysis': [{'lex': 'кормилкин', 'wt': 1, 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'кормилкин'}
# {'analysis': [{'lex': 'прочитывать', 'wt': 1, 'gr': 'V=инф,сов'}], 'text': 'прочитать'}
# {'analysis': [{'lex': 'бездеятельный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}], 'text': 'бездеятельного'}
# {'analysis': [{'lex': 'позволять', 'wt': 1, 'gr': 'V,пе=(непрош,вин,ед,прич,полн,сред,несов,действ|непрош,им,ед,прич,полн,сред,несов,действ)'}], 'text': 'позволяющее'}
# {'analysis': [{'lex': 'крутой', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'крутой'}
# {'analysis': [{'lex': 'миллионер', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'миллионер'}{'analysis': [{'lex': 'президентский', 'wt': 1, 'gr': 'A=(дат,ед,полн,муж|дат,ед,полн,сред)'}], 'text': 'президентскому'}
#
# {'analysis': [{'lex': 'студент', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'студента'}
# {'analysis': [{'lex': 'метко', 'wt': 0.9829038773, 'gr': 'ADV='}], 'text': 'метко'}
# {'analysis': [{'lex': 'тесть', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'тестем'}
# {'analysis': [{'lex': 'на', 'wt': 0.9989522965, 'gr': 'PR='}], 'text': 'на'}
# {'analysis': [{'lex': 'бойкот', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'бойкот'}
# {'analysis': [{'lex': 'судья', 'wt': 1, 'gr': 'S,мж,од=(вин,мн|род,мн)'}], 'text': 'судей'}
# {'analysis': [{'lex': 'дамский', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'дамский'}{'analysis': [{'lex': 'человекоцентризм', 'wt': 1, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'человекоцентризм'}
#
# {'analysis': [{'lex': 'проводить', 'wt': 1, 'gr': 'V=непрош,ед,изъяв,3-л,сов'}], 'text': 'проведёт'}
# {'analysis': [{'lex': 'профорг', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'профорга'}
# {'analysis': [{'lex': 'ромашов', 'wt': 0.8911235595, 'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}], 'text': 'ромашова'}
# {'analysis': [{'lex': 'канал', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'канале'}
# {'analysis': [{'lex': 'тонуть', 'wt': 1, 'gr': 'V,несов,нп=(непрош,пр,мн,прич,полн,действ|непрош,род,мн,прич,полн,действ|непрош,вин,мн,прич,полн,действ,од)'}], 'text': 'тонущих'}
# {'analysis': [{'lex': 'кс', 'wt': 1, 'gr': 'S,сокр=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}], 'text': 'кс'}
# {'analysis': [{'lex': 'варвар', 'wt': 0.9405017056, 'gr': 'S,муж,од=твор,мн'}], 'text': 'варварами'}
# {'analysis': [{'lex': 'студент', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'студент'}
# {'analysis': [{'lex': 'задавать', 'wt': 1, 'gr': 'V,пе=(непрош,вин,ед,прич,полн,муж,несов,действ,од|непрош,род,ед,прич,полн,муж,несов,действ|непрош,род,ед,прич,полн,сред,несов,действ)'}], 'text': 'задающего'}
# {'analysis': [], 'text': 'sobesednik'}{'analysis': [{'lex': 'налаживаться', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,сред,сов'}], 'text': 'наладилось'}
#
# {'analysis': [{'lex': 'внедрять', 'wt': 1, 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}], 'text': 'внедряет'}
# {'analysis': [{'lex': 'владимир', 'wt': 0.9402489048, 'gr': 'S,имя,муж,од=(вин,ед|род,ед)'}], 'text': 'владимира'}
# {'text': '11.00'}
# {'analysis': [{'lex': 'придавать', 'wt': 1, 'gr': 'V,пе=инф,сов'}], 'text': 'придать'}
# {'analysis': [{'lex': 'луддит', 'wt': 1, 'gr': 'S,муж,од=твор,мн'}], 'text': 'луддитами'}
# {'analysis': [{'lex': 'пядь', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'пядей'}
# {'analysis': [], 'text': 'politika'}{'analysis': [{'lex': 'отраслевой', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'отраслевые'}
#
# {'analysis': [{'lex': 'психотрейдинг', 'wt': 1, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'психотрейдинг'}
# {'analysis': [{'lex': 'поступать', 'wt': 1, 'gr': 'V,нп=(прош,дат,мн,прич,полн,сов,действ|прош,твор,ед,прич,полн,муж,сов,действ|прош,твор,ед,прич,полн,сред,сов,действ)'}], 'text': 'поступившим'}
# {'analysis': [{'lex': 'соловьев', 'wt': 0.9890616788, 'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}], 'text': 'соловьева'}
# {'text': '7'}
# {'analysis': [{'lex': 'сочетать', 'wt': 1, 'gr': 'V,пе=(непрош,вин,ед,прич,полн,муж,несов,действ,неод|непрош,им,ед,прич,полн,муж,несов,действ)'}], 'text': 'сочетающий'}
# {'analysis': [{'lex': 'препятствовать', 'wt': 1, 'gr': 'V,несов,нп=непрош,твор,мн,прич,полн,действ'}], 'text': 'препятствующими'}
# {'analysis': [{'lex': 'лоб', 'wt': 1, 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}], 'text': 'лбу'}
# {'analysis': [{'lex': 'владикавказ', 'wt': 1, 'gr': 'S,гео,муж,неод=род,ед'}], 'text': 'владикавказа'}
# {'analysis': [{'lex': 'самарский', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'самарские'}
# {'analysis': [{'lex': 'запас', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'запасы'}
# {'text': '20210601'}
# {'analysis': [{'lex': 'значит', 'wt': 0.7805960181, 'gr': 'ADV,вводн='}], 'text': 'значит'}
# {'analysis': [{'lex': 'рассматривать', 'wt': 1, 'gr': 'V,пе=(непрош,пр,мн,прич,полн,несов,страд|непрош,вин,мн,прич,полн,несов,страд,од|непрош,род,мн,прич,полн,несов,страд)'}], 'text': 'рассматриваемых'}
# {'text': '2018'}
# {'analysis': [{'lex': 'прогресс', 'wt': 1, 'gr': 'S,муж,неод=дат,ед'}], 'text': 'прогрессу'}
# {'analysis': [{'lex': 'усидчивый', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'усидчивый'}{'analysis': [{'lex': 'позволять', 'wt': 1, 'gr': 'V,пе=мн,пов,2-л,сов'}], 'text': 'позвольте'}
#
# {'analysis': [{'lex': 'опасность', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'опасность'}
# {'analysis': [{'lex': 'сердечный', 'wt': 0.9984014421, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'сердечных'}{'analysis': [{'lex': 'муниципалитет', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'муниципалитеты'}
# {'analysis': [{'lex': 'сырой', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'сырой'}
#
# {'analysis': [{'lex': 'несогласие', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'несогласия'}
# {'analysis': [{'lex': 'возрастать', 'wt': 1, 'gr': 'V,нп=(прош,пр,ед,прич,полн,муж,сов,действ|прош,пр,ед,прич,полн,сред,сов,действ)'}], 'text': 'возросшем'}
# {'analysis': [{'lex': 'великоватый', 'wt': 1, 'gr': 'A=ед,кр,сред'}], 'text': 'великовато'}
# {'analysis': [{'lex': 'велеть', 'wt': 1, 'gr': 'V,нп=(прош,мн,изъяв,несов|прош,мн,изъяв,сов)'}], 'text': 'велели'}
# {'analysis': [{'lex': 'вставлять', 'wt': 1, 'gr': 'V,пе=инф,сов'}], 'text': 'вставить'}
# {'analysis': [{'lex': 'больше', 'wt': 0.8140595769, 'gr': 'ADV='}], 'text': 'больше'}{'analysis': [{'lex': 'борукаев', 'wt': 0.7781592766, 'qual': 'bastard', 'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}], 'text': 'борукаева'}{'analysis': [{'lex': 'сокращаться', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'сократились'}
#
#
# {'analysis': [{'lex': 'получать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,сов'}], 'text': 'получили'}
# {'analysis': [{'lex': 'интерес', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'интересе'}
# {'analysis': [{'lex': 'аполитичный', 'wt': 1, 'gr': 'A=ед,кр,муж'}], 'text': 'аполитичен'}
# {'analysis': [{'lex': 'многовато', 'wt': 0.4411852464, 'gr': 'ADV='}], 'text': 'многовато'}
# {'analysis': [{'lex': 'губерниев', 'wt': 0.2903559548, 'qual': 'bastard', 'gr': 'S,фам,муж,од=(дат,мн|твор,ед)'}], 'text': 'губерниевым'}
# {'analysis': [{'lex': 'подробненько', 'wt': 0.4639847478, 'qual': 'bastard', 'gr': 'ADV='}], 'text': 'подробненько'}
# {'analysis': [{'lex': 'иркутский', 'wt': 1, 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'иркутской'}
# {'analysis': [{'lex': 'укреплять', 'wt': 1, 'gr': 'V,пе=прош,деепр,сов'}], 'text': 'укрепив'}
# {'analysis': [{'lex': 'что', 'wt': 0.1976208528, 'gr': 'SPRO,ед,сред,неод=(пр|твор)'}], 'text': 'чем'}
# {'analysis': [{'lex': 'кавалер', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'кавалер'}
# {'analysis': [{'lex': 'чернуха', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'чернухи'}
# {'analysis': [{'lex': 'заданный', 'wt': 0.5857568536, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'заданных'}
# {'analysis': [{'lex': 'неизвестный', 'wt': 0.9989355867, 'gr': 'A=твор,мн,полн'}], 'text': 'неизвестными'}
# {'analysis': [{'lex': 'склока', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}], 'text': 'склокой'}
# {'analysis': [{'lex': 'расписывать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,сов'}], 'text': 'расписал'}
# {'analysis': [{'lex': 'премия', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'премию'}
# {'analysis': [{'lex': 'ужесточение', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}], 'text': 'ужесточении'}
# {'analysis': [{'lex': 'критерий', 'wt': 1, 'gr': 'S,муж,неод=пр,мн'}], 'text': 'критериях'}
# {'analysis': [{'lex': 'обычный', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'обычная'}
# {'analysis': [{'lex': 'супруг', 'wt': 0.5364098433, 'gr': 'S,муж,од=им,ед'}], 'text': 'супруг'}
# {'analysis': [{'lex': 'робер', 'wt': 1, 'gr': 'S,имя,муж,од=дат,ед'}], 'text': 'роберу'}
# {'analysis': [{'lex': 'люто', 'wt': 0.8874421867, 'gr': 'ADV='}], 'text': 'люто'}
# {'analysis': [{'lex': 'ссылочка', 'wt': 1, 'qual': 'bastard', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'ссылочки'}
# {'analysis': [{'lex': 'дамочка', 'wt': 1, 'gr': 'S,жен,од=им,ед'}], 'text': 'дамочка'}
# {'analysis': [{'lex': 'заседание', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}], 'text': 'заседании'}
# {'analysis': [{'lex': 'автомобильный', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'автомобильных'}
# {'analysis': [{'lex': 'функциональность', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'функциональность'}
# {'analysis': [{'lex': 'гарантировать', 'wt': 0.4693645311, 'gr': 'V,пе=(прош,пр,ед,прич,полн,жен,несов,страд|прош,пр,ед,прич,полн,жен,сов,страд|прош,дат,ед,прич,полн,жен,несов,страд|прош,дат,ед,прич,полн,жен,сов,страд|прош,род,ед,прич,полн,жен,несов,страд|прош,род,ед,прич,полн,жен,сов,страд|прош,твор,ед,прич,полн,жен,несов,страд|прош,твор,ед,прич,полн,жен,сов,страд)'}], 'text': 'гарантированной'}{'analysis': [{'lex': 'палить', 'wt': 1, 'gr': 'V,несов,пе=инф'}], 'text': 'палить'}
#
# {'analysis': [{'lex': 'а', 'wt': 0.01124958978, 'gr': 'PART='}], 'text': 'а'}
# {'analysis': [{'lex': 'сопротивляться', 'wt': 1, 'gr': 'V,несов,нп=непрош,мн,изъяв,3-л'}], 'text': 'сопротивляются'}
# {'analysis': [{'lex': 'городской', 'wt': 0.999391271, 'gr': 'A,полн=(пр,мн|род,мн|вин,мн,од)'}], 'text': 'городских'}
# {'analysis': [{'lex': 'проставлять', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,сов'}], 'text': 'проставил'}
# {'analysis': [{'lex': 'яростно', 'wt': 0.9646793525, 'gr': 'ADV='}], 'text': 'яростно'}
# {'analysis': [{'lex': 'основывать', 'wt': 1, 'gr': 'V=прош,вин,ед,прич,полн,жен,сов,страд'}], 'text': 'основанную'}
# {'analysis': [{'lex': 'перевозка', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'перевозок'}
# {'analysis': [{'lex': 'куда', 'wt': 0.9999833027, 'gr': 'ADVPRO='}], 'text': 'куда'}
# {'analysis': [{'lex': 'травмат', 'wt': 0.1385302221, 'qual': 'bastard', 'gr': 'S,муж,неод=род,ед'}], 'text': 'травмата'}
# {'analysis': [{'lex': 'зацепка', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'зацепок'}
# {'analysis': [{'lex': 'осложнение', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'осложнение'}
# {'analysis': [{'lex': 'роса', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'роса'}{'analysis': [{'lex': 'округ', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}], 'text': 'округов'}
#
# {'analysis': [{'lex': 'профорг', 'wt': 1, 'gr': 'S,муж,од=дат,ед'}], 'text': 'профоргу'}
# {'analysis': [{'lex': 'авторитет', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'авторитете'}
# {'analysis': [{'lex': 'нефтегазовый', 'wt': 1, 'gr': 'A,полн=(им,мн|вин,мн,неод)'}], 'text': 'нефтегазовые'}
# {'analysis': [{'lex': 'разнимать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,сов'}], 'text': 'разняли'}{'analysis': [{'lex': 'пенек', 'wt': 0.9800747867, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'пеньки'}
#
# {'analysis': [{'lex': 'грубый', 'wt': 1, 'gr': 'A=(пр,мн,полн,прев|вин,мн,полн,прев,од|род,мн,полн,прев)'}], 'text': 'грубейших'}
# {'analysis': [{'lex': 'доброволец', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'доброволец'}
# {'analysis': [{'lex': 'сходить', 'wt': 1, 'gr': 'V,нп=непрош,ед,изъяв,3-л,сов'}], 'text': 'сойдёт'}
# {'analysis': [{'lex': 'муниципальный', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'муниципальных'}
# {'analysis': [{'lex': 'тетенька', 'wt': 1, 'gr': 'S,жен,од=им,ед'}], 'text': 'тетенька'}
# {'analysis': [{'lex': 'давить', 'wt': 1, 'gr': 'V,несов,пе=непрош,ед,изъяв,3-л'}], 'text': 'давит'}
# {'analysis': [{'lex': 'дорожать', 'wt': 1, 'gr': 'V,несов,нп=непрош,мн,изъяв,3-л'}], 'text': 'дорожают'}
# {'analysis': [{'lex': 'чаевые', 'wt': 0.938653047, 'gr': 'S,мн,неод=(пр|род)'}], 'text': 'чаевых'}
# {'analysis': [{'lex': 'деваться', 'wt': 1, 'gr': 'V,нп=непрош,мн,изъяв,3-л,сов'}], 'text': 'денутся'}
# {'analysis': [{'lex': 'непризнание', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}], 'text': 'непризнании'}
# {'analysis': [{'lex': 'поворот', 'wt': 1, 'gr': 'S,муж,неод=дат,ед'}], 'text': 'повороту'}
# {'analysis': [{'lex': 'образование', 'wt': 1, 'gr': 'S,сред,неод=род,мн'}], 'text': 'образований'}{'analysis': [{'lex': 'шпаргалка', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'шпаргалки'}
#
# {'analysis': [{'lex': 'перепутывать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}], 'text': 'перепутала'}
# {'analysis': [{'lex': 'марка', 'wt': 0.9941584752, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'марки'}
# {'analysis': [{'lex': 'релевантный', 'wt': 1, 'gr': 'A=твор,мн,полн'}], 'text': 'релевантными'}
# {'analysis': [{'lex': 'ну', 'wt': 0.9991076439, 'gr': 'PART='}], 'text': 'ну'}
# {'analysis': [{'lex': 'официант', 'wt': 1, 'gr': 'S,муж,од=дат,мн'}], 'text': 'официантам'}
# {'analysis': [{'lex': 'захотеть', 'wt': 1, 'gr': 'V,сов,пе=непрош,мн,изъяв,3-л'}], 'text': 'захотят'}
# {'analysis': [{'lex': 'чумный', 'wt': 0.1525810041, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'чумные'}
# {'analysis': [{'lex': 'футболист', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'футболиста'}{'analysis': [], 'text': 'brent'}{'analysis': [{'lex': 'оглушать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,сов'}], 'text': 'оглушил'}
#
# {'analysis': [{'lex': 'зал', 'wt': 0.8008588551, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'зале'}
#
# {'analysis': [{'lex': 'вольта', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}], 'text': 'вольтой'}
# {'analysis': [{'lex': 'отбирать', 'wt': 1, 'gr': 'V=инф,сов'}], 'text': 'отобрать'}
# {'analysis': [{'lex': 'разве', 'wt': 0.9472795605, 'gr': 'PART='}], 'text': 'разве'}
# {'analysis': [{'lex': 'щедрый', 'wt': 1, 'gr': 'A=твор,мн,полн'}], 'text': 'щедрыми'}
# {'analysis': [{'lex': 'картофельный', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'картофельные'}
# {'analysis': [{'lex': 'наводнение', 'wt': 1, 'gr': 'S,сред,неод=род,мн'}], 'text': 'наводнений'}
# {'analysis': [{'lex': 'дергаться', 'wt': 1, 'gr': 'V,несов,нп=инф'}], 'text': 'дёргаться'}{'text': '0'}
#
# {'analysis': [{'lex': 'заседание', 'wt': 1, 'gr': 'S,сред,неод=род,мн'}], 'text': 'заседаний'}
# {'analysis': [{'lex': 'оздоева', 'wt': 0.3133495254, 'qual': 'bastard', 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'оздоева'}
# {'analysis': [{'lex': 'дипломат', 'wt': 1, 'gr': 'S,муж,од=твор,мн'}], 'text': 'дипломатами'}
# {'analysis': [{'lex': 'что', 'wt': 0.2934446278, 'gr': 'SPRO,ед,сред,неод=(вин|им)'}], 'text': 'что'}
# {'text': '351'}
# {'analysis': [{'lex': 'стабильно', 'wt': 0, 'gr': 'ADV=срав'}], 'text': 'постабильнее'}
# {'text': '328'}{'analysis': [{'lex': 'георолитический', 'wt': 1, 'qual': 'bastard', 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'георолитических'}
#
# {'analysis': [{'lex': 'иранец', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'иранцем'}
# {'analysis': [{'lex': 'турбулентность', 'wt': 1, 'gr': 'S,жен,неод=(вин,ед|им,ед)'}], 'text': 'турбулентность'}
# {'analysis': [{'lex': 'рассказывать', 'wt': 1, 'gr': 'V=непрош,ед,изъяв,3-л,сов'}], 'text': 'расскажет'}
# {'analysis': [{'lex': 'суслик', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'суслика'}
# {'text': '75'}
# {'analysis': [{'lex': 'совмин', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}], 'text': 'совмина'}
# {'analysis': [{'lex': 'сервильный', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'сервильные'}
# {'text': '1'}{'analysis': [{'lex': 'хороший', 'wt': 0.9996634483, 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'хорошей'}{'analysis': [{'lex': 'сожалеть', 'wt': 1, 'gr': 'V,несов,нп=непрош,ед,изъяв,3-л'}], 'text': 'сожалеет'}
#
# {'analysis': [{'lex': 'константин', 'wt': 1, 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'константин'}
#
# {'analysis': [{'lex': 'замыкать', 'wt': 0.9850635095, 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}], 'text': 'замыкает'}{'analysis': [{'lex': 'азмун', 'wt': 0.7812614922, 'qual': 'bastard', 'gr': 'S,муж,неод=твор,ед'}], 'text': 'азмуном'}{'analysis': [{'lex': 'гоцанюк', 'wt': 0.7923589479, 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'гоцанюк'}
#
#
# {'analysis': [], 'text': 'https'}
# {'analysis': [{'lex': 'прилетать', 'wt': 1, 'gr': 'V,нп=непрош,мн,изъяв,3-л,несов'}], 'text': 'прилетают'}
# {'analysis': [{'lex': 'доказательство', 'wt': 1, 'gr': 'S,сред,неод=род,мн'}], 'text': 'доказательств'}{'analysis': [{'lex': 'онлайн', 'wt': 0.7085577321, 'gr': 'ADV='}], 'text': 'онлайн'}{'analysis': [{'lex': 'кировский', 'wt': 0.670433778, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'кировском'}{'analysis': [{'lex': 'замдира', 'wt': 0.1948601336, 'qual': 'bastard', 'gr': 'S,жен,од=им,ед'}], 'text': 'замдира'}{'analysis': [{'lex': 'зайцев', 'wt': 0.1987737708, 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'зайцев'}
#
#
#
#
# {'text': '560'}
# {'analysis': [{'lex': 'пиарщик', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'пиарщика'}
# {'analysis': [], 'text': 't'}
# {'analysis': [{'lex': 'приманивать', 'wt': 1, 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}], 'text': 'приманивает'}
# {'text': '0'}{'analysis': [{'lex': 'абсолютный', 'wt': 1, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'абсолютное'}
#
# {'analysis': [], 'text': 'me'}
# {'analysis': [{'lex': 'братск', 'wt': 1, 'gr': 'S,гео,муж,неод=(вин,ед|им,ед)'}], 'text': 'братск'}
# {'analysis': [{'lex': 'официант', 'wt': 1, 'gr': 'S,муж,од=им,мн'}], 'text': 'официанты'}
# {'analysis': [{'lex': 'последний', 'wt': 1, 'gr': 'A=твор,мн,полн'}], 'text': 'последними'}{'analysis': [{'lex': 'загрузчик', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'загрузчика'}
#
# {'analysis': [{'lex': 'красноярскмелиоводхоз', 'wt': 0.9311426717, 'qual': 'bastard', 'gr': 'S,муж,неод=род,ед'}], 'text': 'красноярскмелиоводхоза'}
# {'analysis': [{'lex': 'идиотский', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'идиотские'}
# {'text': '278'}
# {'analysis': [{'lex': 'днище', 'wt': 1, 'gr': 'S,сред,неод=(пр,ед|вин,ед|им,ед)'}], 'text': 'днище'}
# {'analysis': [{'lex': 'увеличивать', 'wt': 1, 'gr': 'V,пе=(прош,вин,ед,прич,полн,муж,сов,действ,неод|прош,им,ед,прич,полн,муж,сов,действ)'}], 'text': 'увеличивший'}{'analysis': [], 'text': 'solovievlive'}
#
# {'analysis': [{'lex': 'допвыплата', 'wt': 1, 'qual': 'bastard', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'допвыплаты'}
# {'analysis': [{'lex': 'подоплека', 'wt': 1, 'gr': 'S,жен,неод=пр,мн'}], 'text': 'подоплеках'}
# {'analysis': [{'lex': 'тупак', 'wt': 1, 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'тупак'}
# {'analysis': [], 'text': 'check'}
# {'analysis': [{'lex': 'коряков', 'wt': 0.8688649884, 'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}], 'text': 'корякова'}
# {'text': '0'}
# {'analysis': [{'lex': 'ирак', 'wt': 1, 'gr': 'S,гео,муж,неод=твор,ед'}], 'text': 'ираком'}
# {'text': '63735'}{'text': '373'}
#
# {'analysis': [{'lex': 'инфоцыган', 'wt': 1, 'qual': 'bastard', 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'инфоцыгана'}
# {'analysis': [{'lex': 'технический', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'техническая'}
# {'analysis': [], 'text': 'point'}
# {'text': '80'}
# {'analysis': [{'lex': 'татышев', 'wt': 1, 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'татышев'}
# {'analysis': [{'lex': 'байден', 'wt': 1, 'qual': 'bastard', 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'байден'}{'analysis': [{'lex': 'гусейн', 'wt': 1, 'gr': 'S,имя,муж,од=(вин,ед|род,ед)'}], 'text': 'гусейна'}
#
# {'text': '61'}
# {'text': '1564'}
# {'analysis': [{'lex': 'австралия', 'wt': 1, 'gr': 'S,гео,жен,неод=вин,ед'}], 'text': 'австралию'}
# {'text': '59374'}
# {'analysis': [{'lex': 'плед', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'плед'}
# {'analysis': [{'lex': 'кибершпионский', 'wt': 1, 'qual': 'bastard', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'кибершпионской'}
# {'analysis': [{'lex': 'числова', 'wt': 0.3907784188, 'qual': 'bastard', 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'числова'}
# {'analysis': [{'lex': 'гасанова', 'wt': 0.3907784188, 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'гасанова'}
# {'analysis': [{'lex': 'сказать', 'wt': 1, 'gr': 'V,сов,пе=прош,ед,изъяв,муж'}], 'text': 'сказал'}
# {'analysis': [{'lex': 'поручать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,сред,сов'}], 'text': 'поручило'}{'text': '0'}
#
# {'analysis': [{'lex': 'верблюжий', 'wt': 1, 'gr': 'A,полн=(им,мн|вин,мн,неод)'}], 'text': 'верблюжьи'}
# {'analysis': [{'lex': 'кыргызстанинформационный', 'wt': 0.8284003991, 'qual': 'bastard', 'gr': 'A=им,ед,полн,жен'}], 'text': 'кыргызстанинформационная'}
# {'analysis': [{'lex': 'наслаждаться', 'wt': 1, 'gr': 'V,нп=инф,несов'}], 'text': 'наслаждаться'}
# {'analysis': [{'lex': 'открывать', 'wt': 0.09689512386, 'gr': 'V=прош,ед,прич,кр,муж,сов,страд'}], 'text': 'открыт'}
# {'analysis': [], 'text': 'sharp'}
# {'analysis': [{'lex': 'раскрутка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'раскрутку'}
# {'analysis': [{'lex': 'биишкек', 'wt': 1, 'qual': 'bastard', 'gr': 'S,гео,муж,неод=пр,ед'}], 'text': 'биишкеке'}
# {'analysis': [{'lex': 'володя', 'wt': 1, 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'володя'}{'text': '6696'}
#
# {'analysis': [{'lex': 'прорабатывать', 'wt': 1, 'gr': 'V,пе=инф,сов'}], 'text': 'проработать'}
# {'analysis': [{'lex': 'зашквара', 'wt': 1, 'qual': 'bastard', 'gr': 'S,жен,неод=род,мн'}], 'text': 'зашквар'}
# {'analysis': [{'lex': 'солнце', 'wt': 1, 'gr': 'S,сред,неод=твор,ед'}], 'text': 'солнцем'}
# {'analysis': [{'lex': 'маневр', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}], 'text': 'маневром'}
# {'analysis': [{'lex': 'рассылка', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'рассылки'}
# {'analysis': [{'lex': 'вложиться', 'wt': 1, 'qual': 'bastard', 'gr': 'V,сов,нп=прош,ед,изъяв,жен'}], 'text': 'вложилась'}
# {'analysis': [{'lex': 'голландия', 'wt': 1, 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'голландии'}
# {'analysis': [{'lex': 'прочь', 'wt': 0.9991584639, 'gr': 'ADV='}], 'text': 'прочь'}
# {'analysis': [{'lex': 'сургутнефтегаз', 'wt': 1, 'qual': 'bastard', 'gr': 'S,муж,неод=род,ед'}], 'text': 'сургутнефтегаза'}{'analysis': [{'lex': 'пенек', 'wt': 0.9800747867, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'пеньки'}
#
# {'analysis': [{'lex': 'введение', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'введения'}
# {'analysis': [{'lex': 'подкрадываться', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,муж,сов'}], 'text': 'подкрался'}
# {'analysis': [{'lex': 'скучно', 'wt': 0.7666757779, 'gr': 'ADV='}], 'text': 'скучно'}
# {'analysis': [{'lex': 'содержать', 'wt': 1, 'gr': 'V,несов,пе=(непрош,пр,ед,прич,полн,жен,действ|непрош,дат,ед,прич,полн,жен,действ|непрош,род,ед,прич,полн,жен,действ|непрош,твор,ед,прич,полн,жен,действ)'}], 'text': 'содержащей'}
# {'analysis': [{'lex': 'прокремлевский', 'wt': 1, 'qual': 'bastard', 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'прокремлевской'}
# {'analysis': [{'lex': 'браться', 'wt': 1, 'gr': 'V,несов,нп=непрош,мн,изъяв,1-л'}], 'text': 'беремся'}
# {'analysis': [{'lex': 'акциз', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}], 'text': 'акцизов'}
# {'analysis': [{'lex': 'сексизм', 'wt': 1, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'сексизм'}
# {'text': '0'}
# {'analysis': [{'lex': 'убирать', 'wt': 1, 'gr': 'V=ед,пов,2-л,сов'}], 'text': 'убери'}
# {'analysis': [], 'text': 'vechor'}
# {'analysis': [{'lex': 'грызун', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'грызун'}
# {'analysis': [], 'text': 'docx'}
# {'analysis': [{'lex': 'барышня', 'wt': 1, 'gr': 'S,жен,од=им,ед'}], 'text': 'барышня'}
# {'text': '38'}
# {'analysis': [{'lex': 'входящий', 'wt': 0.06188276539, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред|срав)'}], 'text': 'входящее'}
# {'analysis': [], 'text': 'aavst'}
# {'analysis': [{'lex': 'нелегкая', 'wt': 0.1331873726, 'gr': 'S,жен,неод=(вин,мн|им,мн)'}], 'text': 'нелегкие'}
# {'analysis': [{'lex': 'ведомость', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'ведомостей'}
# {'analysis': [], 'text': 'zhirinovskij'}{'analysis': [{'lex': 'укусить', 'wt': 1, 'gr': 'V,сов,пе=прош,ед,изъяв,муж'}], 'text': 'укусил'}
#
# {'analysis': [{'lex': 'файл', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'файлы'}
# {'analysis': [{'lex': 'народный', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'народная'}{'analysis': [{'lex': 'помешаться', 'wt': 1, 'gr': 'V,сов,нп=прош,мн,изъяв'}], 'text': 'помешались'}
#
# {'analysis': [{'lex': 'именовать', 'wt': 1, 'gr': 'V,несов,пе=непрош,ед,изъяв,3-л'}], 'text': 'именует'}
# {'analysis': [{'lex': 'рассматриваться', 'wt': 1, 'gr': 'V,несов,нп=непрош,ед,изъяв,3-л'}], 'text': 'рассматривается'}{'analysis': [{'lex': 'возлюбленная', 'wt': 0.9133912408, 'gr': 'S,жен,од=вин,ед'}], 'text': 'возлюбленную'}
#
# {'text': '55'}{'analysis': [{'lex': 'политэлита', 'wt': 0.8399185087, 'qual': 'bastard', 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'политэлиты'}
#
# {'analysis': [{'lex': 'нахлобучивать', 'wt': 1, 'gr': 'V,пе=непрош,мн,изъяв,3-л,сов'}], 'text': 'нахлобучат'}
# {'analysis': [{'lex': 'текст', 'wt': 1, 'gr': 'S,муж,неод=дат,ед'}], 'text': 'тексту'}
# {'analysis': [{'lex': 'гениальный', 'wt': 1, 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}], 'text': 'гениальным'}
# {'analysis': [{'lex': 'унижать', 'wt': 1, 'gr': 'V=инф,несов,пе'}], 'text': 'унижать'}
# {'analysis': [{'lex': 'милиция', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'милиция'}
# {'analysis': [{'lex': 'формулировать', 'wt': 1, 'gr': 'V,несов,пе=непрош,деепр'}], 'text': 'формулируя'}{'analysis': [{'lex': 'установление', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'установления'}
#
# {'analysis': [{'lex': 'расставаться', 'wt': 1, 'gr': 'V,нп=инф,несов'}], 'text': 'расставаться'}
# {'analysis': [{'lex': 'тапка', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}], 'text': 'тапкой'}
# {'analysis': [{'lex': 'стоять', 'wt': 0.8700632683, 'gr': 'V,несов,нп=(непрош,вин,ед,прич,полн,муж,действ,неод|непрош,им,ед,прич,полн,муж,действ)'}], 'text': 'стоящий'}
# {'analysis': [{'lex': 'приманка', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'приманок'}
# {'analysis': [{'lex': 'чтить', 'wt': 1, 'gr': 'V,несов=непрош,мн,изъяв,3-л,пе'}], 'text': 'чтят'}{'analysis': [{'lex': 'менеджер', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'менеджером'}
#
# {'analysis': [{'lex': 'протасевич', 'wt': 0.7435319057, 'qual': 'bastard', 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'протасевич'}
# {'analysis': [{'lex': 'итальянский', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'итальянских'}
# {'text': '29'}
# {'analysis': [{'lex': 'налоговый', 'wt': 1, 'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'налоговой'}
# {'analysis': [{'lex': 'коряков', 'wt': 0.900120077, 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'коряков'}
# {'analysis': [{'lex': 'смысл', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'смыслы'}
# {'analysis': [{'lex': 'вьетнам', 'wt': 1, 'gr': 'S,гео,муж,неод=пр,ед'}], 'text': 'вьетнаме'}
# {'analysis': [{'lex': 'обеспечивать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,несов'}], 'text': 'обеспечивал'}
# {'analysis': [{'lex': 'нетакие', 'wt': 0.3483297286, 'qual': 'bastard', 'gr': 'S,мн,неод=(пр|род)'}], 'text': 'нетаких'}
# {'analysis': [{'lex': 'оценивать', 'wt': 1, 'gr': 'V,пе=(мн,пов,1-л,сов|непрош,мн,изъяв,1-л,сов)'}], 'text': 'оценим'}
# {'analysis': [{'lex': 'винтовка', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'винтовок'}
# {'analysis': [{'lex': 'зависимость', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'зависимости'}{'analysis': [{'lex': 'недоговоренность', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'недоговоренности'}
# {'analysis': [{'lex': 'участковый', 'wt': 0.7502983465, 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'участкового'}
#
# {'analysis': [{'lex': 'проект', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'проект'}
# {'analysis': [{'lex': 'подделывать', 'wt': 1, 'gr': 'V,пе=прош,мн,прич,кр,сов,страд'}], 'text': 'подделаны'}
# {'analysis': [{'lex': 'желать', 'wt': 1, 'gr': 'V,несов,пе=(прош,пр,мн,прич,полн,действ|прош,род,мн,прич,полн,действ|прош,вин,мн,прич,полн,действ,од)'}], 'text': 'желавших'}
# {'analysis': [{'lex': 'руководимый', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}], 'text': 'руководимого'}
# {'analysis': [{'lex': 'общежитие', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'общежития'}
# {'analysis': [{'lex': 'шлем', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}], 'text': 'шлемов'}
# {'analysis': [{'lex': 'премия', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'премии'}{'analysis': [{'lex': 'отвечать', 'wt': 1, 'gr': 'V,нп=непрош,ед,изъяв,1-л,несов'}], 'text': 'отвечаю'}
#
# {'analysis': [{'lex': 'затрагивать', 'wt': 1, 'gr': 'V,пе=(мн,пов,1-л,сов|непрош,мн,изъяв,1-л,сов)'}], 'text': 'затронем'}
# {'analysis': [{'lex': 'кино', 'wt': 0.9948335101, 'gr': 'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}], 'text': 'кино'}
# {'analysis': [{'lex': 'легитимный', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}], 'text': 'легитимную'}
# {'analysis': [{'lex': 'захват', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}], 'text': 'захвата'}{'analysis': [{'lex': 'безуглеродный', 'wt': 0.8850137003, 'qual': 'bastard', 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}], 'text': 'безуглеродном'}
#
# {'analysis': [{'lex': 'майдануть', 'wt': 0.3326996198, 'qual': 'bastard', 'gr': 'V,обсц,сов=(прош,пр,мн,прич,полн,страд|прош,вин,мн,прич,полн,страд,од|прош,род,мн,прич,полн,страд)'}, {'lex': 'майдануть', 'wt': 0.3326996198, 'qual': 'bastard', 'gr': 'V,разг,обсц,сов=(прош,пр,мн,прич,полн,страд|прош,вин,мн,прич,полн,страд,од|прош,род,мн,прич,полн,страд)'}], 'text': 'майданутых'}
# {'analysis': [{'lex': 'суточный', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'суточная'}
# {'analysis': [{'lex': 'щекотливый', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'щекотливый'}
# {'analysis': [{'lex': 'благо', 'wt': 0.9946119809, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'блага'}
# {'analysis': [{'lex': 'за', 'wt': 1, 'gr': 'PR='}], 'text': 'за'}{'analysis': [{'lex': 'тулун', 'wt': 1, 'gr': 'S,гео,муж,неод=(вин,ед|им,ед)'}], 'text': 'тулун'}
#
# {'analysis': [{'lex': 'переписка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}], 'text': 'переписку'}
# {'text': '12'}
# {'analysis': [{'lex': 'вольно', 'wt': 0.4355084821, 'gr': 'ADV='}], 'text': 'вольно'}
# {'analysis': [{'lex': 'палермо', 'wt': 1, 'gr': 'S,гео,ед,муж,неод=(пр|вин|дат|род|твор|им)'}], 'text': 'палермо'}
# {'analysis': [{'lex': 'бритни', 'wt': 1, 'gr': 'S,имя,жен,од=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}], 'text': 'бритни'}
# {'analysis': [{'lex': 'набирать', 'wt': 1, 'gr': 'V=прош,мн,изъяв,несов,пе'}], 'text': 'набирали'}{'analysis': [{'lex': 'проходить', 'wt': 0.1766016528, 'gr': 'V,нп=(прош,им,мн,прич,полн,сов,действ|прош,вин,мн,прич,полн,сов,действ,неод)'}], 'text': 'прошедшие'}
# {'analysis': [{'lex': 'провоз', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'провозе'}
#
# {'analysis': [{'lex': 'приманка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'приманка'}
# {'text': '21'}
# {'analysis': [{'lex': 'спирс', 'wt': 0.7324094467, 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'спирс'}
# {'analysis': [{'lex': 'заявление', 'wt': 1, 'gr': 'S,сред,неод=твор,ед'}], 'text': 'заявлением'}
# {'analysis': [{'lex': 'прочее', 'wt': 0.9999350581, 'gr': 'SPRO,сред=(вин,ед|им,ед)'}], 'text': 'прочее'}
# {'analysis': [{'lex': 'сицилия', 'wt': 1, 'gr': 'S,гео,жен,неод=им,ед'}], 'text': 'сицилия'}
# {'analysis': [{'lex': 'загружать', 'wt': 1, 'gr': 'V=прош,ед,изъяв,жен,несов,пе'}], 'text': 'загружала'}{'analysis': [{'lex': 'приглашать', 'wt': 1, 'gr': 'V=прош,мн,изъяв,несов,пе'}], 'text': 'приглашали'}{'analysis': [{'lex': 'забираться', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'забрались'}
#
#
# {'analysis': [{'lex': 'сутки', 'wt': 1, 'gr': 'S,мн,неод=(вин|им)'}], 'text': 'сутки'}
# {'analysis': [{'lex': 'бодайбо', 'wt': 1, 'gr': 'S,гео,ед,муж,неод=(пр|вин|дат|род|твор|им)'}], 'text': 'бодайбо'}
# {'analysis': [{'lex': 'рейтинг', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'рейтинги'}{'text': '12505'}
# {'analysis': [{'lex': 'международный', 'wt': 1, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'международное'}
#
# {'analysis': [{'lex': 'июль', 'wt': 0.9946406805, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'июль'}
# {'analysis': [{'lex': 'это', 'wt': 0.5782735034, 'gr': 'SPRO,ед,сред,неод=пр'}], 'text': 'этом'}
# {'analysis': [{'lex': 'район', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'район'}
# {'analysis': [], 'text': 'dropper'}
# {'analysis': [{'lex': 'гурская', 'wt': 1, 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'гурская'}
# {'analysis': [{'lex': 'аффилированность', 'wt': 1, 'qual': 'bastard', 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'аффилированности'}
# {'analysis': [{'lex': 'скреативлять', 'wt': 1, 'qual': 'bastard', 'gr': 'V,пе=инф,сов'}], 'text': 'скреативить'}
# {'text': '29'}{'analysis': [{'lex': 'энергетический', 'wt': 1, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'энергетическое'}
#
# {'analysis': [{'lex': 'касаться', 'wt': 1, 'gr': 'V,нп=непрош,ед,изъяв,3-л,сов'}], 'text': 'коснется'}
# {'analysis': [{'lex': 'фон', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'фоне'}
# {'analysis': [], 'text': 'royalroad'}{'text': '24'}
#
# {'analysis': [{'lex': 'основательница', 'wt': 1, 'gr': 'S,жен,од=им,ед'}], 'text': 'основательница'}
# {'analysis': [{'lex': 'оргпрестуность', 'wt': 0.07385977677, 'qual': 'bastard', 'gr': 'S,жен,неод=твор,ед'}], 'text': 'оргпрестуностью'}
# {'analysis': [], 'text': 'viralload'}{'analysis': [{'lex': 'бузов', 'wt': 0.6092215812, 'gr': 'S,фам,муж,од=(вин,ед|род,ед)'}], 'text': 'бузова'}
#
# ...
# {'analysis': [], 'text': 'cart'}{'analysis': [], 'text': 'due'}
#
# {'text': '1871'}{'analysis': [{'lex': 'пенек', 'wt': 1, 'gr': 'S,муж,неод=пр,мн'}], 'text': 'пеньках'}{'analysis': [{'lex': 'немецко-фашистский', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'немецко-фашистских'}
#
# {'analysis': [{'lex': 'радушно', 'wt': 0.9792688238, 'gr': 'ADV='}], 'text': 'радушно'}
#
# {'text': '132'}
# {'analysis': [{'lex': 'крупный', 'wt': 1, 'gr': 'A=(пр,мн,полн,прев|вин,мн,полн,прев,од|род,мн,полн,прев)'}], 'text': 'крупнейших'}
# {'analysis': [{'lex': 'десятилетний', 'wt': 1, 'gr': 'A,полн=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}], 'text': 'десятилетней'}
# {'analysis': [{'lex': 'итог', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'итог'}
# {'analysis': [], 'text': 'revenge'}{'analysis': [], 'text': 'august'}
# {'text': '1065'}{'analysis': [{'lex': 'кыргызстанбудет', 'wt': 1, 'qual': 'bastard', 'gr': 'ADV,прдк='}], 'text': 'кыргызстанбудет'}
#
# {'analysis': [{'lex': 'приемная', 'wt': 0.6890664983, 'gr': 'S,жен,неод=им,ед'}], 'text': 'приемная'}
#
# {'analysis': [{'lex': 'новенький', 'wt': 0.7031171453, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'новеньких'}
# {'analysis': [{'lex': 'экономика', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'экономик'}
# {'analysis': [{'lex': 'рейтинговый', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'рейтинговые'}
# {'analysis': [{'lex': 'роман', 'wt': 0.9974712116, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'романы'}
# {'analysis': [], 'text': 'countries'}
# {'analysis': [{'lex': 'вопрос', 'wt': 1, 'gr': 'S,муж,неод=твор,мн'}], 'text': 'вопросами'}{'analysis': [{'lex': 'омурбек', 'wt': 1, 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'омурбек'}{'analysis': [{'lex': 'сдвигаться', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,жен,сов'}], 'text': 'сдвинулась'}
#
# {'text': '269'}
#
# {'analysis': [{'lex': 'влюбляться', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,муж,сов'}], 'text': 'влюбился'}
# {'analysis': [{'lex': 'мир', 'wt': 0.9707176378, 'gr': 'S,муж,неод=род,ед'}], 'text': 'мира'}
# {'analysis': [{'lex': 'отвечать', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,муж,несов'}], 'text': 'отвечал'}
# {'analysis': [{'lex': 'писать', 'wt': 1, 'gr': 'V,несов,пе=ед,пов,2-л'}], 'text': 'пиши'}
# {'analysis': [{'lex': 'грозный', 'wt': 1, 'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}], 'text': 'грозные'}
# {'analysis': [{'lex': 'соколова', 'wt': 0.03243226316, 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'соколова'}{'analysis': [{'lex': 'обращаться', 'wt': 1, 'gr': 'V,нп=непрош,мн,изъяв,3-л,несов'}], 'text': 'обращаются'}
# {'analysis': [{'lex': 'бабанов', 'wt': 1, 'gr': 'S,фам,муж,од=им,ед'}], 'text': 'бабанов'}
# {'analysis': [], 'text': 'plan'}
#
# {'text': '127'}
# {'analysis': [{'lex': 'тот', 'wt': 0.9993386898, 'gr': 'APRO=(пр,мн|род,мн|вин,мн,од)'}], 'text': 'тех'}
# {'analysis': [{'lex': 'осознавать', 'wt': 1, 'gr': 'V,пе=(непрош,вин,ед,прич,полн,муж,несов,действ,неод|непрош,им,ед,прич,полн,муж,несов,действ)'}], 'text': 'осознающий'}
# {'analysis': [{'lex': 'зона', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'зон'}
# {'analysis': [{'lex': 'предупреждение', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'предупреждения'}
# {'analysis': [{'lex': 'сатиричный', 'wt': 1, 'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}], 'text': 'сатиричным'}{'analysis': [], 'text': 'formally'}
#
# {'analysis': [{'lex': 'экс-премьер', 'wt': 1, 'gr': 'S,муж,од=им,ед'}], 'text': 'экс-премьер'}
# {'analysis': [{'lex': 'обсуждать', 'wt': 1, 'gr': 'V=(мн,пов,1-л,сов|непрош,мн,изъяв,1-л,сов)'}], 'text': 'обсудим'}
# {'text': '919'}
# {'analysis': [{'lex': 'пора', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}], 'text': 'пор'}
# {'analysis': [{'lex': 'нарочно', 'wt': 0.9998591522, 'gr': 'ADV='}], 'text': 'нарочно'}
# {'analysis': [{'lex': 'переубеждать', 'wt': 1, 'gr': 'V=непрош,ед,изъяв,2-л,сов'}], 'text': 'переубедишь'}
# {'analysis': [{'lex': 'небезопасный', 'wt': 1, 'gr': 'A=ед,кр,жен'}], 'text': 'небезопасна'}
# {'analysis': [], 'text': 'roadmaps'}{'analysis': [{'lex': 'роль', 'wt': 0.9970048948, 'gr': 'S,жен,неод=дат,мн'}], 'text': 'ролям'}
# {'analysis': [{'lex': 'омурбек', 'wt': 1, 'gr': 'S,имя,муж,од=(вин,ед|род,ед)'}], 'text': 'омурбека'}
# {'analysis': [{'lex': 'политолог', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'политологом'}
#
# {'text': '347'}
# {'analysis': [{'lex': 'продолжать', 'wt': 1, 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}], 'text': 'продолжает'}
# {'analysis': [{'lex': 'контратака', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'контратаки'}
# {'analysis': [{'lex': 'преступность', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'преступности'}
# {'analysis': [{'lex': 'недомыслие', 'wt': 1, 'gr': 'S,сред,неод=дат,ед'}], 'text': 'недомыслию'}
# {'analysis': [{'lex': 'загнать', 'wt': 1, 'gr': 'V,сов,пе=прош,ед,изъяв,муж'}], 'text': 'загнал'}
# {'analysis': [{'lex': 'бабанова', 'wt': 0.07878692018, 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'бабанова'}{'analysis': [], 'text': 'littlebig'}
# {'analysis': [], 'text': 'either'}
#
# {'analysis': [{'lex': 'аналитик', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'аналитиком'}
# {'analysis': [{'lex': 'лишь', 'wt': 0.9548535059, 'gr': 'PART='}], 'text': 'лишь'}
# {'analysis': [{'lex': 'устанавливать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,сред,сов'}], 'text': 'установило'}
# {'analysis': [{'lex': 'настраивать', 'wt': 0.9410143821, 'gr': 'V,пе=прош,ед,прич,кр,муж,сов,страд'}], 'text': 'настроен'}
# {'analysis': [{'lex': 'теракт', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'теракты'}
# {'analysis': [], 'text': 'september'}
# {'analysis': [], 'text': 'ся'}
# {'analysis': [{'lex': 'спортбар', 'wt': 0.347972917, 'qual': 'bastard', 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'спортбар'}{'analysis': [{'lex': 'возглавлять', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}], 'text': 'возглавила'}
#
# {'analysis': [{'lex': 'координатор', 'wt': 0.7508689064, 'gr': 'S,муж,од=твор,ед'}], 'text': 'координатором'}
# {'analysis': [{'lex': 'потерять', 'wt': 1, 'gr': 'V,сов,пе=непрош,ед,изъяв,3-л'}], 'text': 'потеряет'}
# {'analysis': [{'lex': 'впритык', 'wt': 1, 'gr': 'ADV='}], 'text': 'впритык'}
# {'analysis': [{'lex': 'складываться', 'wt': 1, 'gr': 'V,нп=(прош,пр,мн,прич,полн,сов,действ|прош,род,мн,прич,полн,сов,действ|прош,вин,мн,прич,полн,сов,действ,од)'}], 'text': 'сложившихся'}
# {'analysis': [{'lex': 'плохой', 'wt': 1, 'gr': 'A=им,ед,полн,прев,жен'}], 'text': 'худшая'}
# {'analysis': [], 'text': 'october'}{'analysis': [{'lex': 'ощущать', 'wt': 1, 'gr': 'V,пе=инф,сов'}], 'text': 'ощутить'}
#
# {'analysis': [{'lex': 'присестьзаведующий', 'wt': 0.9385886306, 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'}], 'text': 'присестьзаведующий'}{'analysis': [{'lex': 'рита', 'wt': 1, 'gr': 'S,имя,жен,од=им,ед'}], 'text': 'рита'}
#
# {'analysis': [{'lex': 'приемная', 'wt': 0.7587368762, 'gr': 'S,жен,неод=(пр,ед|дат,ед|род,ед|твор,ед)'}], 'text': 'приёмной'}
# {'analysis': [{'lex': 'белоруссия', 'wt': 1, 'gr': 'S,гео,жен,неод=вин,ед'}], 'text': 'белоруссию'}
# {'analysis': [{'lex': 'вырастать', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}], 'text': 'выросли'}
# {'analysis': [{'lex': 'казаться', 'wt': 1, 'gr': 'V,несов,нп=прош,мн,изъяв'}], 'text': 'казались'}
# {'analysis': [{'lex': 'предтрансферный', 'wt': 1, 'qual': 'bastard', 'gr': 'A,полн=(вин,ед,сред|им,ед,сред)'}], 'text': 'предтрансферное'}
# {'analysis': [{'lex': 'житель', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}], 'text': 'жителем'}
# {'analysis': [{'lex': 'пальчун', 'wt': 0.7171468802, 'qual': 'bastard', 'gr': 'S,муж,од=(вин,ед|род,ед)'}], 'text': 'пальчуна'}{'analysis': [{'lex': 'токтогулович', 'wt': 1, 'qual': 'bastard', 'gr': 'S,отч,муж,од=им,ед'}], 'text': 'токтогулович'}
#
# {'analysis': [{'lex': 'элегантный', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'элегантный'}
# {'analysis': [], 'text': 'have'}
# {'analysis': [{'lex': 'уступать', 'wt': 1, 'gr': 'V,пе=непрош,ед,изъяв,3-л,сов'}], 'text': 'уступит'}
# {'analysis': [{'lex': 'охотхозяйство', 'wt': 0.6458484267, 'qual': 'bastard', 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'охотхозяйства'}
# {'analysis': [{'lex': 'злой', 'wt': 0.5106455326, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж|пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}], 'text': 'злой'}
# {'analysis': [{'lex': 'анонсирование', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'анонсирование'}
# {'analysis': [{'lex': 'гольяново', 'wt': 1, 'gr': 'S,гео,ед,сред,неод=(пр|вин|дат|род|твор|им)'}], 'text': 'гольяново'}
# {'analysis': [{'lex': 'проектор', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'проектор'}{'analysis': [{'lex': 'следственный', 'wt': 1, 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}], 'text': 'следственном'}{'analysis': [], 'text': 'finalized'}
#
#
# {'analysis': [{'lex': 'предусмотренный', 'wt': 0.08747697886, 'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}], 'text': 'предусмотренного'}
# {'analysis': [{'lex': 'центральный', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}], 'text': 'центральную'}
# {'analysis': [{'lex': 'резвиться', 'wt': 1, 'gr': 'V,несов,нп=непрош,мн,изъяв,3-л'}], 'text': 'резвятся'}
# {'analysis': [{'lex': 'провокация', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}], 'text': 'провокацией'}
# {'analysis': [{'lex': 'обухов', 'wt': 0.987587464, 'gr': 'S,фам,муж,од=(дат,мн|твор,ед)'}], 'text': 'обуховым'}
# {'analysis': [{'lex': 'обострять', 'wt': 1, 'gr': 'V,пе=инф,несов'}], 'text': 'обострять'}
# {'analysis': [], 'text': 'lg'}
# {'analysis': [], 'text': 'integration'}
# {'analysis': [{'lex': 'изолятор', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}], 'text': 'изоляторе'}
# {'analysis': [{'lex': 'санкция', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'санкция'}
# {'analysis': [{'lex': 'азия', 'wt': 1, 'gr': 'S,гео,жен,неод=вин,ед'}], 'text': 'азию'}
# {'analysis': [{'lex': 'заповедник', 'wt': 1, 'gr': 'S,муж,неод=род,мн'}], 'text': 'заповедников'}
# {'analysis': [{'lex': 'неумный', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'неумных'}
# {'analysis': [{'lex': 'приличный', 'wt': 1, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'приличное'}
# {'analysis': [{'lex': 'инкриминировать', 'wt': 1, 'gr': 'V,пе=(непрош,мн,изъяв,3-л,несов|непрош,мн,изъяв,3-л,сов)'}], 'text': 'инкриминируют'}
# {'analysis': [{'lex': 'подключаться', 'wt': 1, 'gr': 'V,нп=мн,пов,2-л,несов'}], 'text': 'подключайтесь'}{'analysis': [], 'text': 'cinebeam'}{'text': '45032'}
#
#
# {'analysis': [], 'text': 'roadmap'}
# {'analysis': [{'lex': 'турция', 'wt': 1, 'gr': 'S,гео,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}], 'text': 'турции'}
# {'text': '47'}
# {'analysis': [{'lex': 'идти', 'wt': 1, 'gr': 'V,несов,нп=(непрош,вин,ед,прич,полн,муж,действ,од|непрош,род,ед,прич,полн,муж,действ|непрош,род,ед,прич,полн,сред,действ)'}], 'text': 'идущего'}
# {'analysis': [{'lex': 'известный', 'wt': 1, 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}], 'text': 'известном'}
# {'analysis': [{'lex': 'шумовой', 'wt': 1, 'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}], 'text': 'шумовое'}
# {'analysis': [], 'text': 'on'}
# {'analysis': [{'lex': 'савва', 'wt': 1, 'gr': 'S,имя,муж,од=(род,ед|им,мн)'}], 'text': 'саввы'}{'analysis': [{'lex': 'стрим', 'wt': 1, 'gr': 'S,муж,неод=дат,ед'}], 'text': 'стриму'}
#
# {'analysis': [], 'text': 'hu'}
# {'analysis': [{'lex': 'там', 'wt': 0.9102368948, 'gr': 'ADVPRO='}], 'text': 'там'}
# {'analysis': [{'lex': 'ушлый', 'wt': 1, 'gr': 'A,полн=(им,мн|вин,мн,неод)'}], 'text': 'ушлые'}
# {'analysis': [{'lex': 'питер', 'wt': 0.9281075599, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}], 'text': 'питер'}
# {'analysis': [{'lex': 'впускать', 'wt': 1, 'gr': 'V=инф,сов'}], 'text': 'впустить'}
# {'analysis': [{'lex': 'далекий', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'далёкий'}
# {'text': '810'}
# {'analysis': [], 'text': 'policy'}
# {'analysis': [{'lex': 'федосеева', 'wt': 0.08981927953, 'gr': 'S,фам,жен,од=им,ед'}], 'text': 'федосеева'}
# {'analysis': [], 'text': 'obuhovprohttps'}
# {'analysis': [{'lex': 'уже', 'wt': 0.9985784456, 'gr': 'ADV='}], 'text': 'уже'}
# {'analysis': [{'lex': 'обустраивать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,сов'}], 'text': 'обустроили'}
# {'analysis': [{'lex': 'полный', 'wt': 0.993007543, 'gr': 'A=ед,кр,муж'}], 'text': 'полон'}
# {'analysis': [{'lex': 'жээнчорой', 'wt': 1, 'qual': 'bastard', 'gr': 'S,муж,од=(вин,мн|род,мн)'}], 'text': 'жээнчороев'}
# {'analysis': [{'lex': 'испаряться', 'wt': 1, 'gr': 'V,нп=прош,ед,изъяв,жен,сов'}], 'text': 'испарилась'}
# {'analysis': [], 'text': 'pw'}
# {'analysis': [], 'text': 'also'}
# {'analysis': [], 'text': 'uorbf'}
# {'analysis': [{'lex': 'ленивый', 'wt': 1, 'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}], 'text': 'ленивый'}
# {'analysis': [{'lex': 'больший', 'wt': 0.02200145973, 'gr': 'A=им,ед,полн,жен'}], 'text': 'большая'}
# {'text': '591'}
# {'analysis': [{'lex': 'построиться', 'wt': 1, 'gr': 'V,сов,нп=прош,ед,изъяв,жен'}], 'text': 'построилась'}
# {'analysis': [{'lex': 'притяжение', 'wt': 1, 'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'притяжения'}
# {'analysis': [{'lex': 'хищение', 'wt': 1, 'gr': 'S,сред,неод=род,мн'}], 'text': 'хищений'}
# {'analysis': [{'lex': 'диагональ', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}], 'text': 'диагональю'}
# {'analysis': [], 'text': 'almost'}
# {'analysis': [], 'text': 'mjfxi'}
# {'analysis': [{'lex': 'календарик', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}], 'text': 'календарики'}
# {'analysis': [{'lex': 'война', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'война'}
# {'analysis': [{'lex': 'охотхозяйство', 'wt': 0.5468892077, 'qual': 'bastard', 'gr': 'S,сред,неод=(вин,ед|им,ед)'}], 'text': 'охотхозяйство'}
# {'analysis': [{'lex': 'двинуться', 'wt': 1, 'gr': 'V,сов,нп=прош,ед,изъяв,жен'}], 'text': 'двинулась'}
# {'analysis': [], 'text': 'done'}
# {'analysis': [{'lex': 'организовывать', 'wt': 1, 'gr': 'V=прош,ед,прич,кр,сред,сов,страд'}], 'text': 'организовано'}
# {'analysis': [{'lex': 'пропажа', 'wt': 1, 'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}], 'text': 'пропажи'}
# {'analysis': [{'lex': 'дюйм', 'wt': 0.9700020658, 'gr': 'S,муж,неод=род,мн'}], 'text': 'дюймов'}
# {'analysis': [{'lex': 'переживать', 'wt': 1, 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}], 'text': 'переживает'}
# {'analysis': [{'lex': 'вырвиглазной', 'wt': 1, 'qual': 'bastard', 'gr': 'A,полн=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|вин,ед,муж,неод|им,ед,муж)'}], 'text': 'вырвиглазной'}
# {'analysis': [{'lex': 'обозначаться', 'wt': 1, 'gr': 'V,нп=непрош,ед,изъяв,3-л,сов'}], 'text': 'обозначится'}
# {'analysis': [{'lex': 'общедоступный', 'wt': 1, 'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}], 'text': 'общедоступных'}
# {'analysis': [{'lex': 'здание', 'wt': 1, 'gr': 'S,сред,неод=дат,ед'}], 'text': 'зданию'}
# {'analysis': [], 'text': 'reconciling'}
# {'analysis': [{'lex': 'прорисовываться', 'wt': 1, 'gr': 'V,нп=непрош,ед,изъяв,3-л,несов'}], 'text': 'прорисовывается'}{'analysis': [{'lex': 'вежливый', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}], 'text': 'вежливая'}
#
# {'analysis': [{'lex': 'цветопередача', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}], 'text': 'цветопередача'}
# {'analysis': [{'lex': 'жанр', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}], 'text': 'жанра'}
# {'analysis': [{'lex': 'федор', 'wt': 0.9279204042, 'gr': 'S,имя,муж,од=(вин,ед|род,ед)'}], 'text': 'фёдора'}
# {'analysis': [{'lex': 'вишенка', 'wt': 1, 'gr': 'S,гео,жен,неод=твор,ед'}], 'text': 'вишенкой'}
# {'analysis': [{'lex': 'охотничий', 'wt': 1, 'gr': 'A,полн=(пр,мн|род,мн|вин,мн,од)'}], 'text': 'охотничьих'}
# {'analysis': [{'lex': 'устраивать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,жен,сов'}], 'text': 'устроила'}
# {'analysis': [], 'text': 'such'}
# {'analysis': [{'lex': 'яркий', 'wt': 0.9938462388, 'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}], 'text': 'ярком'}
# {'analysis': [{'lex': 'фан', 'wt': 1, 'gr': 'S,имя,муж,од=им,ед'}], 'text': 'фан'}
# {'analysis': [{'lex': 'одалживать', 'wt': 1, 'gr': 'V,пе=прош,ед,изъяв,муж,сов'}], 'text': 'одолжил'}
# {'analysis': [{'lex': 'оказываться', 'wt': 1, 'gr': 'V,нп=прош,деепр,сов'}], 'text': 'оказавшись'}
# {'analysis': [{'lex': 'грудина', 'wt': 0.6404238072, 'gr': 'S,жен,неод=им,ед'}], 'text': 'грудина'}

# %% [markdown]
# Закрываем бд

# %%
#con.close()
